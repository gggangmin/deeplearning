# %%
# %run ../chap08/cnn_reg_model.ipynb
# %run ../chap05/dataset_flowers.ipynb
# %run ../chap06/dataset_office31.ipynb

# %%
fd = FlowersDataset([96, 96], [96, 96, 3])
od = Office31Dataset([96, 96], [96, 96, 3])

# %%
fm1 = CnnRegModel('flowers_model_1', fd, [30,10])
fm1.exec_all(epoch_count=10, report=2, show_params=True)
# Out:
# Model flowers_model_1 train started:
#     Epoch 2: cost=1.470, accuracy=0.323/0.340 (26/26 secs)
#     Epoch 4: cost=1.440, accuracy=0.334/0.290 (18/44 secs)
#     Epoch 6: cost=1.475, accuracy=0.308/0.210 (18/62 secs)
#     Epoch 8: cost=1.369, accuracy=0.385/0.270 (18/80 secs)
#     Epoch 10: cost=1.364, accuracy=0.399/0.330 (18/98 secs)
# Model flowers_model_1 train ended in 98 secs:
# Model flowers_model_1 test report: accuracy = 0.363, (1 secs)
#
# Model flowers_model_1 Visualization
# 추정확률분포 [30,40,14, 4,13] => 추정 dandelion : 정답 daisy => X
# 추정확률분포 [12,20,20,20,28] => 추정 tulip : 정답 sunflower => X
# 추정확률분포 [ 1, 1,56, 0,42] => 추정 rose : 정답 tulip => X
# Near 0 parameters =  0.0%(203/829790)

# %%
fm2 = CnnRegModel('flowers_model_2', fd, [30,10], l2_decay=0.1)
fm2.exec_all(epoch_count=10, show_cnt=0, show_params=True)
# Out:
# Model flowers_model_2 train ended in 544 secs:
# Model flowers_model_2 test report: accuracy = 0.232, (0 secs)
# Near 0 parameters =  0.0%(297/829790)

# %%
fm3 = CnnRegModel('flowers_model_3', fd, [30,10], l1_decay=0.01)
fm3.exec_all(epoch_count=10, show_cnt=0, show_params=True)
# Out:
# Model flowers_model_3 train ended in 543 secs:
# Model flowers_model_3 test report: accuracy = 0.232, (1 secs)
# Near 0 parameters = 72.3%(599708/829790)

# %%
cnn1 = [['conv',{'ksize':3, 'chn':6}],
        ['max',{'stride':2}],
        ['conv',{'ksize':3, 'chn':12}],
        ['max',{'stride':2}],
        ['conv',{'ksize':3, 'chn':24}],
        ['avg',{'stride':3}]]
fcnn1 = CnnRegModel('flowers_cnn_1', fd, cnn1)
fcnn1.exec_all(epoch_count=10, report=2)
# Out:
# Model flowers_cnn_1 train started:
#     Epoch 2: cost=1.117, accuracy=0.553/0.580 (196/196 secs)
#     Epoch 4: cost=0.935, accuracy=0.644/0.590 (195/391 secs)
#     Epoch 6: cost=0.797, accuracy=0.704/0.570 (195/586 secs)
#     Epoch 8: cost=0.667, accuracy=0.746/0.630 (196/782 secs)
#     Epoch 10: cost=0.585, accuracy=0.786/0.630 (193/975 secs)
# Model flowers_cnn_1 train ended in 975 secs:
# Model flowers_cnn_1 test report: accuracy = 0.646, (5 secs)
#
# Model flowers_cnn_1 Visualization
# 추정확률분포 [ 4,70, 1, 3,23] => 추정 dandelion : 정답 tulip => X
# 추정확률분포 [30,45,20, 0, 4] => 추정 dandelion : 정답 daisy => X
# 추정확률분포 [ 0, 0,24, 0,76] => 추정 tulip : 정답 rose => X

# %%
cnn2 = [['conv',{'ksize':3, 'chn':6}],
        ['max',{'stride':2}],
        ['dropout', {'keep_prob':0.6}],
        ['conv',{'ksize':3, 'chn':12}],
        ['max',{'stride':2}],
        ['dropout', {'keep_prob':0.6}],
        ['conv',{'ksize':3, 'chn':24}],
        ['avg',{'stride':3}],
        ['dropout', {'keep_prob':0.6}]]
fcnn2 = CnnRegModel('flowers_cnn_2', fd, cnn2)
fcnn2.exec_all(epoch_count=10, report=2, show_cnt=0)
# Out:
# Model flowers_cnn_2 train started:
#     Epoch 2: cost=1.162, accuracy=0.526/0.410 (205/205 secs)
#     Epoch 4: cost=0.996, accuracy=0.612/0.470 (203/408 secs)
#     Epoch 6: cost=0.927, accuracy=0.636/0.470 (202/610 secs)
#     Epoch 8: cost=0.871, accuracy=0.659/0.550 (203/813 secs)
#     Epoch 10: cost=0.839, accuracy=0.672/0.510 (189/1002 secs)
# Model flowers_cnn_2 train ended in 1002 secs:
# Model flowers_cnn_2 test report: accuracy = 0.448, (4 secs)

# %%
noise_std = 0.01
cnn3 = [['noise', {'type':'normal','mean':0,'std':noise_std}],
        ['conv',{'ksize':3, 'chn':6}],
        ['max',{'stride':2}],
        ['noise', {'type':'normal','mean':0,'std':noise_std}],
        ['conv',{'ksize':3, 'chn':12}],
        ['max',{'stride':2}],
        ['noise', {'type':'normal','mean':0,'std':noise_std}],
        ['conv',{'ksize':3, 'chn':24}],
        ['avg',{'stride':3}]]
fcnn3 = CnnRegModel('flowers_cnn_3', fd, cnn3)
fcnn3.exec_all(epoch_count=10, report=2, show_cnt=0)
# Out:
# Model flowers_cnn_3 train started:
#     Epoch 2: cost=1.136, accuracy=0.549/0.590 (193/193 secs)
#     Epoch 4: cost=0.913, accuracy=0.653/0.470 (194/387 secs)
#     Epoch 6: cost=0.796, accuracy=0.703/0.620 (193/580 secs)
#     Epoch 8: cost=0.663, accuracy=0.761/0.690 (194/774 secs)
#     Epoch 10: cost=0.550, accuracy=0.793/0.630 (194/968 secs)
# Model flowers_cnn_3 train ended in 968 secs:
# Model flowers_cnn_3 test report: accuracy = 0.644, (4 secs)

# %%
cnn4 = [['batch_normal'],
        ['conv',{'ksize':3, 'chn':6}],
        ['max',{'stride':2}],
        ['batch_normal'],
        ['conv',{'ksize':3, 'chn':12}],
        ['max',{'stride':2}],
        ['batch_normal'],
        ['conv',{'ksize':3, 'chn':24}],
        ['avg',{'stride':3}]]
fcnn4 = CnnRegModel('flowers_cnn_4', fd, cnn4)
fcnn4.exec_all(epoch_count=10, report=2, show_cnt=0)
# Out:
# Model flowers_cnn_4 train started:
#     Epoch 2: cost=1.036, accuracy=0.600/0.450 (207/207 secs)
#     Epoch 4: cost=0.881, accuracy=0.672/0.400 (201/408 secs)
#     Epoch 6: cost=0.773, accuracy=0.701/0.390 (201/609 secs)
#     Epoch 8: cost=0.677, accuracy=0.756/0.530 (202/811 secs)
#     Epoch 10: cost=0.625, accuracy=0.765/0.640 (210/1021 secs)
# Model flowers_cnn_4 train ended in 1021 secs:
# Model flowers_cnn_4 test report: accuracy = 0.581, (6 secs)

# %%
ocnn1 = CnnRegModel('office31_cnn_1', od, cnn1)
ocnn2 = CnnRegModel('office31_cnn_2', od, cnn2)
ocnn3 = CnnRegModel('office31_cnn_3', od, cnn3)
ocnn4 = CnnRegModel('office31_cnn_4', od, cnn4)

ocnn1.exec_all(epoch_count=10, show_cnt=0)
ocnn2.exec_all(epoch_count=10, show_cnt=0)
ocnn3.exec_all(epoch_count=10, show_cnt=0)
ocnn4.exec_all(epoch_count=10, show_cnt=0)
# Out:
# Model office31_cnn_1 train ended in 924 secs:
# Model office31_cnn_1 test report: accuracy = 0.899+0.538, (5 secs)
#
# Model office31_cnn_2 train ended in 962 secs:
# Model office31_cnn_2 test report: accuracy = 0.126+0.290, (5 secs)
#
# Model office31_cnn_3 train ended in 1001 secs:
# Model office31_cnn_3 test report: accuracy = 0.898+0.541, (4 secs)
#
# Model office31_cnn_4 train ended in 1028 secs:
# Model office31_cnn_4 test report: accuracy = 0.890+0.478, (5 secs)
