# %%
# %run ../chap07/cnn_basic_model.ipynb
# %run ../chap05/dataset_flowers.ipynb
# %run ../chap06/dataset_office31.ipynb

# %%
fd = FlowersDataset([96, 96], [96, 96, 3])
od = Office31Dataset([96, 96], [96, 96, 3])

# %%
fm1 = CnnBasicModel('flowers_model_1', fd, [30, 10])
fm1.exec_all(epoch_count = 10, report = 2)
# Out:
# Model flowers_model_1 train started:
#     Epoch 2: cost=1.470, accuracy=0.323/0.340 (22/22 secs)
#     Epoch 4: cost=1.440, accuracy=0.334/0.290 (14/36 secs)
#     Epoch 6: cost=1.475, accuracy=0.308/0.210 (14/50 secs)
#     Epoch 8: cost=1.369, accuracy=0.385/0.270 (14/64 secs)
#     Epoch 10: cost=1.364, accuracy=0.399/0.330 (14/78 secs)
# Model flowers_model_1 train ended in 78 secs:
# Model flowers_model_1 test report: accuracy = 0.363, (0 secs)
#
# Model flowers_model_1 Visualization
# 추정확률분포 [30,40,14, 4,13] => 추정 dandelion : 정답 daisy => X
# 추정확률분포 [12,20,20,20,28] => 추정 tulip : 정답 sunflower => X
# 추정확률분포 [ 1, 1,56, 0,42] => 추정 rose : 정답 tulip => X

# %%
fm2 = CnnBasicModel('flowers_model_2', fd, 
                    [['full', {'width':30}], 
                     ['full', {'width':10}]])
fm2.use_adam = False
fm2.exec_all(epoch_count = 10, report = 2)
# Out:
# Model flowers_model_2 train started:
#     Epoch 2: cost=1.599, accuracy=0.260/0.280 (5/5 secs)
#     Epoch 4: cost=1.497, accuracy=0.343/0.270 (6/11 secs)
#     Epoch 6: cost=1.358, accuracy=0.395/0.330 (5/16 secs)
#     Epoch 8: cost=1.295, accuracy=0.423/0.430 (6/22 secs)
#     Epoch 10: cost=1.239, accuracy=0.461/0.360 (6/28 secs)
# Model flowers_model_2 train ended in 28 secs:
# Model flowers_model_2 test report: accuracy = 0.396, (0 secs)
#
# Model flowers_model_2 Visualization
# 추정확률분포 [ 0, 0,68, 0,31] => 추정 rose : 정답 rose => O
# 추정확률분포 [ 8,23,14,30,25] => 추정 sunflower : 정답 dandelion => X
# 추정확률분포 [18,16,29,11,27] => 추정 rose : 정답 sunflower => X

# %%
fm3 = CnnBasicModel('flowers_model_3', fd, 
               [['conv', {'ksize':5, 'chn':6}], 
                ['max', {'stride':4}], 
                ['conv', {'ksize':3, 'chn':12}], 
                ['avg', {'stride':2}]], 
               True)
fm3.exec_all(epoch_count = 10, report = 2)
# Out:
# Model flowers_model_3 train started:
#     Epoch 2: cost=1.206, accuracy=0.518/0.530 (250/250 secs)
#     Epoch 4: cost=0.932, accuracy=0.645/0.580 (251/501 secs)
#     Epoch 6: cost=0.788, accuracy=0.698/0.670 (250/751 secs)
#     Epoch 8: cost=0.628, accuracy=0.768/0.550 (251/1002 secs)
#     Epoch 10: cost=0.518, accuracy=0.805/0.600 (248/1250 secs)
# Model flowers_model_3 train ended in 1250 secs:
# Model flowers_model_3 test report: accuracy = 0.564, (6 secs)
#
# Model flowers_model_3 Visualization
# 추정확률분포 [ 5,13, 2, 0,80] => 추정 tulip : 정답 tulip => O
# 추정확률분포 [ 6,48, 1,14,31] => 추정 dandelion : 정답 dandelion => O
# 추정확률분포 [15, 2,49, 5,29] => 추정 rose : 정답 daisy => X

# %%
fm4 = CnnBasicModel('flowers_model_4', fd, 
               [['conv', {'ksize':3, 'chn':6}], 
                ['max', {'stride':2}], 
                ['conv', {'ksize':3, 'chn':12}], 
                ['max', {'stride':2}], 
                ['conv', {'ksize':3, 'chn':24}], 
                ['avg', {'stride':3}]])
fm4.exec_all(epoch_count = 10, report = 2)
# Out:
# Model flowers_model_4 train started:
#     Epoch 2: cost=1.151, accuracy=0.546/0.520 (181/181 secs)
#     Epoch 4: cost=0.929, accuracy=0.639/0.570 (181/362 secs)
#     Epoch 6: cost=0.788, accuracy=0.708/0.610 (180/542 secs)
#     Epoch 8: cost=0.675, accuracy=0.744/0.600 (181/723 secs)
#     Epoch 10: cost=0.558, accuracy=0.802/0.740 (182/905 secs)
# Model flowers_model_4 train ended in 905 secs:
# Model flowers_model_4 test report: accuracy = 0.661, (4 secs)
#
# Model flowers_model_4 Visualization
# 추정확률분포 [ 2,64,11,12,12] => 추정 dandelion : 정답 dandelion => O
# 추정확률분포 [ 3,12,18, 5,61] => 추정 tulip : 정답 tulip => O
# 추정확률분포 [ 4, 0,96, 0, 0] => 추정 rose : 정답 tulip => X

# %%
om1 = CnnBasicModel('office31_model_1', od, 
               [['conv', {'ksize':3, 'chn':6}], 
                ['max', {'stride':2}], 
                ['conv', {'ksize':3, 'chn':12}], 
                ['max', {'stride':2}], 
                ['conv', {'ksize':3, 'chn':24}], 
                ['avg', {'stride':3}]])
om1.exec_all(epoch_count = 10, report = 2)
# Out:
# Model office31_model_1 train started:
#     Epoch 2: cost=2.673, accuracy=0.830+0.397/0.830+0.380 (173/173 secs)
#     Epoch 4: cost=1.564, accuracy=0.903+0.636/0.820+0.500 (173/346 secs)
#     Epoch 6: cost=0.891, accuracy=0.934+0.793/0.860+0.570 (175/521 secs)
#     Epoch 8: cost=0.516, accuracy=0.944+0.891/0.830+0.490 (174/695 secs)
#     Epoch 10: cost=0.319, accuracy=0.966+0.933/0.880+0.510 (172/867 secs)
# Model office31_model_1 train ended in 867 secs:
# Model office31_model_1 test report: accuracy = 0.896+0.536, (4 secs)
#
# Model office31_model_1 Visualization
# [ 도메인 추정결과 ]
# 추정확률분포 [69, 0,31] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [100, 0, 0] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [100, 0, 0] => 추정 amazon : 정답 amazon => O
# [ 상품 추정결과 ]
# 추정확률분포 [ 0, 2, 0, 0, 0, 0, 0, 0,...] => 추정 pen : 정답 scissors => X
# 추정확률분포 [ 0, 0, 0, 0, 0, 0, 0, 0,...] => 추정 punchers : 정답 phone => X
# 추정확률분포 [ 0, 0, 0,100, 0, 0, 0, 0,...] => 추정 bookcase : 정답 paper_notebook => X

# %%
om1.exec_all(epoch_count = 40, show_cnt = 0)
# Out:
# Model office31_model_1 train ended in 3414 secs:
# Model office31_model_1 test report: accuracy = 0.890+0.547, (4 secs)

# %%
om2 = CnnBasicModel('office31_model_2', od, 
               [['conv', {'ksize':3, 'chn':6, 'actfunc':'sigmoid'}], 
                ['max', {'stride':2}], 
                ['conv', {'ksize':3, 'chn':12, 'actfunc':'sigmoid'}], 
                ['max', {'stride':2}], 
                ['conv', {'ksize':3, 'chn':24, 'actfunc':'sigmoid'}], 
                ['avg', {'stride':3}]])
om2.exec_all(epoch_count = 10, report = 2)
# Out:
# Model office31_model_2 train started:
#     Epoch 2: cost=4.268, accuracy=0.686+0.031/0.700+0.010 (181/181 secs)
#     Epoch 4: cost=4.259, accuracy=0.686+0.038/0.610+0.010 (180/361 secs)
#     Epoch 6: cost=4.261, accuracy=0.686+0.035/0.620+0.010 (178/539 secs)
#     Epoch 8: cost=4.259, accuracy=0.686+0.037/0.670+0.020 (178/717 secs)
#     Epoch 10: cost=4.259, accuracy=0.686+0.039/0.620+0.030 (179/896 secs)
# Model office31_model_2 train ended in 896 secs:
# Model office31_model_2 test report: accuracy = 0.693+0.040, (6 secs)
#
# Model office31_model_2 Visualization
# [ 도메인 추정결과 ]
# 추정확률분포 [70,11,19] => 추정 amazon : 정답 dslr => X
# 추정확률분포 [70,11,19] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [71,11,18] => 추정 amazon : 정답 dslr => X
# [ 상품 추정결과 ]
# 추정확률분포 [ 3, 3, 3, 2, 2, 3, 4, 3,...] => 추정 monitor : 정답 mouse => X
# 추정확률분포 [ 3, 3, 3, 2, 2, 3, 4, 3,...] => 추정 monitor : 정답 tape_dispenser => X
# 추정확률분포 [ 3, 3, 3, 2, 2, 3, 4, 3,...] => 추정 monitor : 정답 desk_chair => X

# %%
om3 = CnnBasicModel('office31_model_3', od, 
               [['conv', {'ksize':3, 'chn':6, 'actfunc':'tanh'}], 
                ['max', {'stride':2}], 
                ['conv', {'ksize':3, 'chn':12, 'actfunc':'tanh'}], 
                ['max', {'stride':2}], 
                ['conv', {'ksize':3, 'chn':24, 'actfunc':'tanh'}], 
                ['avg', {'stride':3}]])
om3.exec_all(epoch_count = 10, report = 2)
# Out:
# Model office31_model_3 train started:
#     Epoch 2: cost=3.723, accuracy=0.695+0.204/0.690+0.220 (181/181 secs)
#     Epoch 4: cost=2.962, accuracy=0.762+0.383/0.680+0.360 (181/362 secs)
#     Epoch 6: cost=2.726, accuracy=0.784+0.434/0.840+0.330 (180/542 secs)
#     Epoch 8: cost=2.600, accuracy=0.782+0.452/0.610+0.240 (179/721 secs)
#     Epoch 10: cost=2.227, accuracy=0.818+0.526/0.810+0.330 (182/903 secs)
# Model office31_model_3 train ended in 903 secs:
# Model office31_model_3 test report: accuracy = 0.814+0.392, (5 secs)
#
# Model office31_model_3 Visualization
# [ 도메인 추정결과 ]
# 추정확률분포 [64,10,27] => 추정 amazon : 정답 webcam => X
# 추정확률분포 [97, 0, 3] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [97, 2, 1] => 추정 amazon : 정답 amazon => O
# [ 상품 추정결과 ]
# 추정확률분포 [ 0, 0, 0, 0, 0, 0, 1,13,...] => 추정 mug : 정답 keyboard => X
# 추정확률분포 [ 0, 1, 0, 3, 0, 0, 6, 0,...] => 추정 file_cabinet : 정답 speaker => X
# 추정확률분포 [ 0, 0, 1, 0, 0, 0, 0, 0,...] => 추정 letter_tray : 정답 letter_tray => O
